# %% [markdown]
# ![%E0%B8%9B%E0%B8%81%E0%B8%9A%E0%B8%97%E0%B9%80%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B8%99%20%285%29.png](attachment:%E0%B8%9B%E0%B8%81%E0%B8%9A%E0%B8%97%E0%B9%80%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B8%99%20%285%29.png)

# %% [markdown]
# # อย่าลืมกดซับให้ถึงล้านซับ

# %% [markdown]
# ช่วยเราถึงเป้าหมายโดยการชวนเพื่อนมากด subscribe youtube [Ultimate Python](https://bit.ly/ultimatepython-youtube)

# %% [markdown]
# # สิ่งที่เราทำบนเวปไซต์

# %% [markdown]
# หากลองศึกษาสิ่งที่เราทำบนเวปไซต์แล้วจะพบว่าจริงๆ แล้วการทำงานกับเวปไซต์มีแค่ไม่กี่อย่างเท่านั้น เช่น การคลิก และการพิมพ์ข้อมูล แต่ความแตกต่างของแต่ละเวปไซต์ คือ การที่มีส่วนประกอบไม่เหมือนกัน
#
# ดังนั้นหลักการที่สำคัญขงอการทำงานบนเวปไซต์แท้จริงแล้ว คือ การระบุตำแหน่งบนหน้าเวปไซต์ที่เราต้องการจะคลิก หรือพิมพ์ข้อความใส่ ซึ่งเป็นหลักการที่เราจะได้ทดลองทำกับโปรแกรมตัวอย่างในวันนี้

# %% [markdown]
# # การทำงานกับข้อมูลเวปไซต์

# %% [markdown]
# ข้อมูลที่เราเห็นบนเวปไซต์เป็นผลลัพธ์ของโค้ด HTML ที่ไปดึงข้อมูลต่างๆ มาจัดเรียงให้สวยงามตามที่ตาเราเห็น โดย Browser จะทำความเข้าใจโค้ด HTML และเข้าไปดึงข้อความ รูป วิดีโอ หรือข้อมูลอื่นๆ ตามที่ HTML ตัวนั้นระบุจากอินเตอร์เน็ต และตีความออกมาเป็นหน้าเวปที่สวยงาม
#
# โค้ด HTML จะประกอบไปด้วยส่วนย่อยที่เรียกว่า HTML Tags ที่แบ่งส่วนการรับผิดชอบการแสดงผลของหน้าเวปแต่ละส่วนโดยมีลักษณะที่ซ้อนกันลงไปเป็นชั้นๆ เช่น HTML Tags ที่รับผิดชอบหน้าเวปทั้งหมด จะประกอบไปด้วย HTML Tags ที่รับผิดชอบหน้าเวปด้านบน และ HTML Tags ที่รับผิดชอบแถบโฆษณาด้านล่าง เป็นต้น
#
# หลักการสำคัญของการทำงานกับข้อมูลหน้าเวปในคลิปนี้ คือ การระบุ HTML Tags ที่เหมาะสมเพื่อการดึงข้อมูลที่เราต้องการ ให้สามารถดึงข้อมูลที่เกิดซ้ำๆ ได้อย่างมีประสิทธิภาพ โดยผ่านการระบุ ชื่อ และ Attribute
#
# สำหรับ Chrome เราสามารถดูโค้ด HTML ของเวปใดๆ ได้โดยการกด F12 (ในการเรียนรู้ในคลิปนี้แนะนำให้ติดตั้ง [Chrome](google.com/chrome/?brand=BNSD&gclid=Cj0KCQiA7NKBBhDBARIsAHbXCB4C87Cfd3clf7Sc6P5gNTcHbqcru_-xc_HKq-hqYPvyETvIR8oLeeAaAghVEALw_wcB&gclsrc=aw.ds))

# %% [markdown]
# # ตัวอย่างโปรแกรมลดงาน

# %% [markdown]
# ในตัวอย่างจะเป็นการสร้างโปรแกรมจาก 0 เพื่อดาวน์โหลดรายงานงบการเงินของบริษัทใน SET50 หรือ 50 บริษัทที่มีมูลค่าสูงสุดในตลาด ที่อยู่ใน [หน้าเวปนี้](https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&language=th&country=TH) ให้ครบทุกบริษัทแบบอัตโนมัติ

# %% [markdown]
# ## ขั้นตอนการทำงานคร่าวๆ ของโปรแกรม

# %% [markdown]
# ดึงลิ้งค์ของทุกเวปไซต์ใน SET50 >> นำลิ้งค์ไปเปิดเข้าเวปบริษัท >> คลิกเข้าตามขั้นตอนจนถึงการดาวน์โหลด >> ทำซ้ำจนดาวน์โหลดไฟล์ครบของทุกบริษัท

# %% [markdown]
# ## การใช้งาน

# %% [markdown]
# หากต้องการทดลองใช้งานให้กด / คลิกที่สัญลักษณ์ `In [ ]` สีน้ำเงินด้านซ้ายของหน้ากระดาษนี้ และกดปุ่ม `Run` ตามด้านล่าง ทำซ้ำจนครบทุกอัน โดยจะต้องทำตามลำดับจากอันด้านบนลงไปด้านล่างของกระดาษ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# หากต้องการดูโฟลเดอร์ของไฟล์ Jupyter Notebook นี้ให้กดที่ File >> Open แล้วโฟลเดอร์ที่ไฟล์ Jupyter Notebook นี้อยู่จะถูกเปิดขึ้น

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ทดลองเขียนตามขั้นตอน

# %% [markdown]
# สำหรับคนที่อยากทดลองเขียนตามคลิปสอน [Ultimate Python](https://www.facebook.com/ultimatepython) ได้เรียบเรียงขั้นตอนแยกไว้ให้เรียนรู้ตามได้ง่ายตามขั้นตอนด้านล่าง สำหรับคนที่อยากเห็นโปรแกรมตัวเต็มสามารถดูได้จากด้านล่างของเอกสารนี้เลย

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %% [markdown]
# ## นำเข้าเครื่องมือ

# %% [markdown]
# ## เก็บลิ้งค์เวปของทุกบริษัท

# %% [markdown]
# ## คลิกตามขั้นตอนเพื่อดาวน์โหลดไฟล์

# %% [markdown]
# ## ทำซ้ำกับทุกบริษัทจนครบ

# %% [markdown]
# ## พิมพ์ข้อความใส่ช่องบนเวป

# %% [markdown]
# ## กดส่งรหัสให้ทางเวปไซต์

# %% [markdown]
# # โปรแกรมจากตัวอย่าง

# %% [markdown]
# เมื่อทำความเข้าใจตามคลิป และเข้าใจการทำงานของโปรแกรมตัวนี้แล้ว สามารถปรับใช้ได้ตามต้องการเลย

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %%
pip install selenium

# %% [markdown]
# ## นำเข้าเครื่องมือ

# %%
from selenium import webdriver

# %% [markdown]
# ## เก็บลิ้งค์เวปของทุกบริษัท

# %%
company_list = []
driver = webdriver.Chrome()
driver.get('https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&language=th&country=TH')
for data in driver.find_elements_by_xpath('//table[@class="table-info"]//tbody//tr//td[@style="text-align: left;"]//a')[8:]:
    company_list.append(data.get_attribute('href'))

# %% [markdown]
# ## คลิกตามขั้นตอนเพื่อดาวน์โหลดไฟล์

# %%
for company in company_list:
    driver.get(company)
    driver.find_elements_by_xpath('//div[@class="row"]//li[@role="tab"]')[1].click()
    driver.find_elements_by_xpath('//div[@class="col-xs-12 col-md-4 text-center"][@style="border-left: 1px solid #000000;"]')[-1].click()
    driver.find_elements_by_xpath('//table[@class="table table-hover table-info"]//tbody//tr[@height="18"]//td[@height="18"]')[-1].click()

# %% [markdown]
# ## กำหนด ID, Password

# %%
email = ''
password = ''

# %% [markdown]
# ## พิมพ์ ID, Password และส่งให้เวปไซต์

# %%
driver.find_element_by_xpath('//input[@placeholder="E-mail or Username"]').send_keys(email)
driver.find_element_by_xpath('//input[@placeholder="Password"]').send_keys(password)
driver.find_element_by_xpath('//input[@value="ลงชื่อเข้าใช้"]').submit()

# %% [markdown]
# # อยากมีเพื่อนแลกเปลี่ยนความรู้ Python

# %% [markdown]
# เข้าร่วมกลุ่ม [ลดงานด้วยPython](https://www.facebook.com/ultimatepython) โชว์ผลงาน หาไอเดียจากท่านอื่น หรือโพสสอบถามแลกเปลี่ยนได้เลย

# %% [markdown]
# # ให้เราช่วยคุณ

# %% [markdown]
# อยากเขียนเองเป็น อยากออกแบบระบบเองได้ แต่ไม่อยากลองผิดลองถูกเอง เรียนกับ "คอร์สลดงานด้วย Python" กับ Ultimate Python จาก 0 ได้เลย เรียนรู้เพิ่มเติมได้ที่ www.ultimatepython.co

# %% [markdown]
# ![%E0%B8%8A%E0%B9%88%E0%B8%A7%E0%B8%A2%E0%B9%80%E0%B8%A3%E0%B8%B2%E0%B8%8A%E0%B9%88%E0%B8%A7%E0%B8%A2%E0%B8%84%E0%B8%B8%E0%B8%93%20%E0%B9%80%E0%B8%82%E0%B9%89%E0%B8%B2%E0%B9%83%E0%B8%88%20Python%20%281%29.png](attachment:%E0%B8%8A%E0%B9%88%E0%B8%A7%E0%B8%A2%E0%B9%80%E0%B8%A3%E0%B8%B2%E0%B8%8A%E0%B9%88%E0%B8%A7%E0%B8%A2%E0%B8%84%E0%B8%B8%E0%B8%93%20%E0%B9%80%E0%B8%82%E0%B9%89%E0%B8%B2%E0%B9%83%E0%B8%88%20Python%20%281%29.png)
